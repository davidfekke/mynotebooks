# %%
a = 3
b = 5

# %%
print(f"This is a testing script. {a}")
# Out:
# This is a testing script. 3

# %%
name = input("What is your name?")
print(name)
# Out:
# David

# %%
print(f"Your name is {name}!")
# Out:
# Your name is David!
