# %%
import torch

def print_value(a):
    print(f"Your value is  {a}")

print_value(1245)
print(torch.__version__)
# Out:
# Your value is  1245
# 2.9.1

# %%
import torch
x = torch.rand(5, 3)
print(x)
# Out:
# tensor([[0.1018, 0.1994, 0.0986],
#         [0.3916, 0.9183, 0.2459],
#         [0.0213, 0.0151, 0.9035],
#         [0.5142, 0.8838, 0.2435],
#         [0.5682, 0.2388, 0.2256]])

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
